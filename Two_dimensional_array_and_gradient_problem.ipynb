# %% [markdown]
# <a href="https://colab.research.google.com/github/jigjid/github_task/blob/main/Two_dimensional_array_and_gradient_problem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [Problem 1] Linear function

# %%
import numpy as np
x = np.arange(-50,50.1,0.1).reshape(1001)
x
# Out:
# array([-50. , -49.9, -49.8, ...,  49.8,  49.9,  50. ])

# %%
y = 1/2*x+1
y
# Out:
# array([-24.  , -23.95, -23.9 , ...,  25.9 ,  25.95,  26.  ])

# %% [markdown]
# [Problem 2] Array combination

# %%
a=np.stack((x,y),axis=1)
a
# Out:
# array([[-50.  , -24.  ],
#        [-49.9 , -23.95],
#        [-49.8 , -23.9 ],
#        ...,
#        [ 49.8 ,  25.9 ],
#        [ 49.9 ,  25.95],
#        [ 50.  ,  26.  ]])

# %% [markdown]
# [Problem 3] Find the gradient

# %%
x_grad = x[1:] - x[:-1]
y_grad = y[1:] - y[:-1]
gradient = y_grad/x_grad
gradient
# Out:
# array([0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
# ...

# %% [markdown]
# [Problem 4] Draw a graph

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
x1 = np.arange(-50,50,0.1)
ax.plot(x1,gradient)
plt.show()

# %% [markdown]
# [Problem 5] Python functionalization

# %%
def compute_gradient(function, x_range=(-50, 50.1, 0.1)):
    x_range : tuple
    x = np.arange(*x_range)
    x_size = x.size
    array_x = x.reshape((x_size,1))
    array_xy = np.concatenate((array_x,function), axis=1)
    gradient = (array_x[1:]-array_x[:-1])/(function[1:]-function[:-1])
    pass
    return array_xy, gradient
def function1(array_x=np.arange(-50,50.1,0.1).reshape((1001,1))):
  array_y = array_x**2
  pass
  return array_y
def function2(array_x=np.arange(-50,50.1,0.1).reshape((1001,1))):
  array_y = 2*array_x**2+2**array_x
  pass
  return array_y
def function3(array_x=np.arange(0, 50.1, 0.1).reshape((501,1))):
  array_y = np.sin(np.sqrt(array_x))
  pass
  return array_y

# %%
array_xy, gradient1 = compute_gradient(function1())
print(array_xy)
print(gradient1)
# Out:
# [[ -50.   2500.  ]
#  [ -49.9  2490.01]
#  [ -49.8  2480.04]
#  ...
#  [  49.8  2480.04]
#  [  49.9  2490.01]
#  [  50.   2500.  ]]
# [[ -0.01001001]
#  [ -0.01003009]
#  [ -0.01005025]
#  [ -0.01007049]
#  [ -0.01009082]
#  [ -0.01011122]
#  [ -0.01013171]
#  [ -0.01015228]
#  [ -0.01017294]
#  [ -0.01019368]
#  [ -0.0102145 ]
#  [ -0.01023541]
#  [ -0.01025641]
#  [ -0.01027749]
#  [ -0.01029866]
#  [ -0.01031992]
#  [ -0.01034126]
#  [ -0.01036269]
#  [ -0.01038422]
#  [ -0.01040583]
#  [ -0.01042753]
#  [ -0.01044932]
#  [ -0.0104712 ]
#  [ -0.01049318]
#  [ -0.01051525]
#  [ -0.01053741]
#  [ -0.01055966]
#  [ -0.01058201]
#  [ -0.01060445]
#  [ -0.01062699]
#  [ -0.01064963]
#  [ -0.01067236]
#  [ -0.01069519]
#  [ -0.01071811]
#  [ -0.01074114]
#  [ -0.01076426]
#  [ -0.01078749]
#  [ -0.01081081]
#  [ -0.01083424]
#  [ -0.01085776]
#  [ -0.01088139]
#  [ -0.01090513]
#  [ -0.01092896]
#  [ -0.0109529 ]
#  [ -0.01097695]
#  [ -0.0110011 ]
#  [ -0.01102536]
#  [ -0.01104972]
# ...

# %%
fig, ax = plt.subplots()
x1 = np.arange(-50,50,0.1)
ax.plot(x1,gradient1)
plt.show()

# %%
array_xy2, gradient2 = compute_gradient(function2())
fig, ax = plt.subplots()
x2 = np.arange(-50,50,0.1)
ax.plot(x2,gradient2)
plt.show()

# %%
array_xy3, gradient3 = compute_gradient(function3(),x_range=(0, 50.1, 0.1))
fig, ax = plt.subplots()
x3 = np.arange(0,50,0.1)
ax.plot(x3,gradient3)
plt.show()

# %% [markdown]
# Problem 6] Find the minimum value

# %%
a=np.min(function1())
b=np.min(function2())
c=np.min(function3())
print('minimum value function1={}'.format(a))
print('minimum value function2={}'.format(b))
print('minimum value function3={}'.format(c))
# Out:
# minimum value function1=5.048709793414476e-25
# minimum value function2=0.9505505632959851
# minimum value function3=-0.9999997540298113
